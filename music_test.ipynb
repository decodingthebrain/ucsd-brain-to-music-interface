# %%
# !pip install sounddevice
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import sounddevice as sd

# %%
my_array = np.array([0, 0.5, 1, 0.5, 0], dtype=np.float32)  # Example audio data

fs = 44100  # Sample rate
# sd.play(my_array, fs)
# sd.stop()

# make sample rate default
sd.default.samplerate = fs
sd.play(my_array)
sd.stop()

# %%
# see available devices for output/input
#sd.query_devices()

# %%
# !pip install spotipy
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="83838f0d51524cec9ef8a3d89b054a23", ))
